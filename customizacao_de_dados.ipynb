# %% [markdown]
# Colunas
#
# 1. acidez_fixa (g(ácido_tartárico)/dm³)
#
# 2. acidez_volátil (g(ácido_acético)/dm³)
#
# 3. ácido_cítrico (g/dm³)
#
# 4. açúcar_residual (g/dm³)
#
# 5. cloretos (g(cloreto_de_sódio)/dm³)
#
# 6. dióxido de enxofre livre (mg/dm³)
#
# 7. dióxido de enxofre total (mg/dm³)
#
# 8. densidade (g/cm³)
#
# 9. pH
#
# 10. sulfatos (g(sulfato_de_potássio)/dm³)
#
# 11. teor alcoólico (% vol.)

# %%
import pandas as pd

# Carregamento do arquivo CSV em um DataFrame do Pandas e substituição de ponto e vírgula por vírgula
vinho_branco_dados = pd.read_csv('vinho_branco.csv', sep=';', delimiter=None, engine='python')

# Dicionário de tradução dos nomes das colunas
traducao_colunas = {
    'fixed acidity': 'acidez_fixa',
    'volatile acidity': 'acidez_volatil',
    'citric acid': 'acido_citrico',
    'residual sugar': 'acucar_residual',
    'chlorides': 'cloreto',
    'free sulfur dioxide': 'dioxido_enxofre_livre',
    'total sulfur dioxide': 'dioxido_enxofre_total',
    'density': 'densidade',
    'pH': 'pH',
    'sulphates': 'sulfatos',
    'alcohol': 'alcool',
    'quality': 'qualidade'
}

# Renomeie as colunas com os nomes em português e padrão snake_case
vinho_branco_dados.rename(columns=traducao_colunas, inplace=True)

# Modifique o índice para começar em 1
vinho_branco_dados.index = vinho_branco_dados.index + 1

# Salve o DataFrame em um novo arquivo CSV
vinho_branco_dados.to_csv('analise_vinho_branco.csv', sep=',', index_label='indice')

# Imprima o DataFrame no formato de tabela (no Jupyter Notebook, basta digitar o nome do DataFrame)
vinho_branco_dados
# Out:
#       acidez_fixa  acidez_volatil  acido_citrico  acucar_residual  cloreto  \
# 1             7.0            0.27           0.36             20.7    0.045
# 2             6.3            0.30           0.34              1.6    0.049
# 3             8.1            0.28           0.40              6.9    0.050
# 4             7.2            0.23           0.32              8.5    0.058
# 5             7.2            0.23           0.32              8.5    0.058
# ...           ...             ...            ...              ...      ...
# 4894          6.2            0.21           0.29              1.6    0.039
# 4895          6.6            0.32           0.36              8.0    0.047
# 4896          6.5            0.24           0.19              1.2    0.041
# 4897          5.5            0.29           0.30              1.1    0.022
# 4898          6.0            0.21           0.38              0.8    0.020
#
# ...
